# %%
% matplotlib notebook

import pygrib
#import requests
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
#import datetime
#import scipy.interpolate
#import os

# %%
grbs = pygrib.open("1979010100.grb")

# %%
grbs.message
# Out:
# 328

# %%
for i in range(1, 328):
    print(grbs[i])
# Out:
# 1:Surface pressure:Pa (instant):regular_gg:surface:level 0:fcst time 6 hrs:from 197901010000
# 2:Total Precipitation:kg m**-2 (accum):regular_gg:surface:level 0:fcst time 0-6 hrs (accum):from 197901010000
# 3:Water temperature:K (instant):regular_gg:surface:level 0:fcst time 6 hrs:from 197901010000
# 4:Snow fall rate water equivalent:kg m**-2 s**-1 (instant):regular_gg:surface:level 0:fcst time 6 hrs:from 197901010000
# 5:10 metre U wind component:m s**-1 (instant):regular_gg:heightAboveGround:level 10:fcst time 6 hrs:from 197901010000
# 6:10 metre V wind component:m s**-1 (instant):regular_gg:heightAboveGround:level 10:fcst time 6 hrs:from 197901010000
# 7:2 metre temperature:K (instant):regular_gg:heightAboveGround:level 2:fcst time 6 hrs:from 197901010000
# 8:Specific humidity:kg kg**-1 (instant):regular_gg:heightAboveGround:level 2:fcst time 6 hrs:from 197901010000
# 9:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 1:fcst time 6 hrs:from 197901010000
# 10:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 1:fcst time 6 hrs:from 197901010000
# 11:Temperature:K (instant):regular_gg:hybrid:level 1:fcst time 6 hrs:from 197901010000
# 12:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 1:fcst time 6 hrs:from 197901010000
# 13:Geopotential Height:gpm (instant):regular_gg:hybrid:level 1:fcst time 6 hrs:from 197901010000
# 14:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 1:fcst time 6 hrs:from 197901010000
# 15:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 1:fcst time 6 hrs:from 197901010000
# 16:230:230 (instant):regular_gg:hybrid:level 1:fcst time 6 hrs:from 197901010000
# 17:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 2:fcst time 6 hrs:from 197901010000
# 18:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 2:fcst time 6 hrs:from 197901010000
# 19:Temperature:K (instant):regular_gg:hybrid:level 2:fcst time 6 hrs:from 197901010000
# 20:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 2:fcst time 6 hrs:from 197901010000
# 21:Geopotential Height:gpm (instant):regular_gg:hybrid:level 2:fcst time 6 hrs:from 197901010000
# 22:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 2:fcst time 6 hrs:from 197901010000
# 23:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 2:fcst time 6 hrs:from 197901010000
# 24:230:230 (instant):regular_gg:hybrid:level 2:fcst time 6 hrs:from 197901010000
# 25:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 3:fcst time 6 hrs:from 197901010000
# 26:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 3:fcst time 6 hrs:from 197901010000
# 27:Temperature:K (instant):regular_gg:hybrid:level 3:fcst time 6 hrs:from 197901010000
# 28:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 3:fcst time 6 hrs:from 197901010000
# 29:Geopotential Height:gpm (instant):regular_gg:hybrid:level 3:fcst time 6 hrs:from 197901010000
# 30:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 3:fcst time 6 hrs:from 197901010000
# 31:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 3:fcst time 6 hrs:from 197901010000
# 32:230:230 (instant):regular_gg:hybrid:level 3:fcst time 6 hrs:from 197901010000
# 33:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 4:fcst time 6 hrs:from 197901010000
# 34:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 4:fcst time 6 hrs:from 197901010000
# 35:Temperature:K (instant):regular_gg:hybrid:level 4:fcst time 6 hrs:from 197901010000
# 36:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 4:fcst time 6 hrs:from 197901010000
# 37:Geopotential Height:gpm (instant):regular_gg:hybrid:level 4:fcst time 6 hrs:from 197901010000
# 38:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 4:fcst time 6 hrs:from 197901010000
# 39:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 4:fcst time 6 hrs:from 197901010000
# 40:230:230 (instant):regular_gg:hybrid:level 4:fcst time 6 hrs:from 197901010000
# 41:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 5:fcst time 6 hrs:from 197901010000
# 42:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 5:fcst time 6 hrs:from 197901010000
# 43:Temperature:K (instant):regular_gg:hybrid:level 5:fcst time 6 hrs:from 197901010000
# 44:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 5:fcst time 6 hrs:from 197901010000
# 45:Geopotential Height:gpm (instant):regular_gg:hybrid:level 5:fcst time 6 hrs:from 197901010000
# 46:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 5:fcst time 6 hrs:from 197901010000
# 47:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 5:fcst time 6 hrs:from 197901010000
# 48:230:230 (instant):regular_gg:hybrid:level 5:fcst time 6 hrs:from 197901010000
# 49:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 6:fcst time 6 hrs:from 197901010000
# 50:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 6:fcst time 6 hrs:from 197901010000
# 51:Temperature:K (instant):regular_gg:hybrid:level 6:fcst time 6 hrs:from 197901010000
# 52:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 6:fcst time 6 hrs:from 197901010000
# 53:Geopotential Height:gpm (instant):regular_gg:hybrid:level 6:fcst time 6 hrs:from 197901010000
# 54:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 6:fcst time 6 hrs:from 197901010000
# 55:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 6:fcst time 6 hrs:from 197901010000
# 56:230:230 (instant):regular_gg:hybrid:level 6:fcst time 6 hrs:from 197901010000
# 57:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 7:fcst time 6 hrs:from 197901010000
# 58:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 7:fcst time 6 hrs:from 197901010000
# 59:Temperature:K (instant):regular_gg:hybrid:level 7:fcst time 6 hrs:from 197901010000
# 60:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 7:fcst time 6 hrs:from 197901010000
# 61:Geopotential Height:gpm (instant):regular_gg:hybrid:level 7:fcst time 6 hrs:from 197901010000
# 62:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 7:fcst time 6 hrs:from 197901010000
# 63:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 7:fcst time 6 hrs:from 197901010000
# 64:230:230 (instant):regular_gg:hybrid:level 7:fcst time 6 hrs:from 197901010000
# 65:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 8:fcst time 6 hrs:from 197901010000
# 66:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 8:fcst time 6 hrs:from 197901010000
# 67:Temperature:K (instant):regular_gg:hybrid:level 8:fcst time 6 hrs:from 197901010000
# 68:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 8:fcst time 6 hrs:from 197901010000
# 69:Geopotential Height:gpm (instant):regular_gg:hybrid:level 8:fcst time 6 hrs:from 197901010000
# 70:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 8:fcst time 6 hrs:from 197901010000
# 71:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 8:fcst time 6 hrs:from 197901010000
# 72:230:230 (instant):regular_gg:hybrid:level 8:fcst time 6 hrs:from 197901010000
# 73:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 9:fcst time 6 hrs:from 197901010000
# 74:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 9:fcst time 6 hrs:from 197901010000
# 75:Temperature:K (instant):regular_gg:hybrid:level 9:fcst time 6 hrs:from 197901010000
# 76:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 9:fcst time 6 hrs:from 197901010000
# 77:Geopotential Height:gpm (instant):regular_gg:hybrid:level 9:fcst time 6 hrs:from 197901010000
# 78:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 9:fcst time 6 hrs:from 197901010000
# 79:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 9:fcst time 6 hrs:from 197901010000
# 80:230:230 (instant):regular_gg:hybrid:level 9:fcst time 6 hrs:from 197901010000
# 81:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 10:fcst time 6 hrs:from 197901010000
# 82:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 10:fcst time 6 hrs:from 197901010000
# 83:Temperature:K (instant):regular_gg:hybrid:level 10:fcst time 6 hrs:from 197901010000
# 84:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 10:fcst time 6 hrs:from 197901010000
# 85:Geopotential Height:gpm (instant):regular_gg:hybrid:level 10:fcst time 6 hrs:from 197901010000
# 86:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 10:fcst time 6 hrs:from 197901010000
# 87:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 10:fcst time 6 hrs:from 197901010000
# 88:230:230 (instant):regular_gg:hybrid:level 10:fcst time 6 hrs:from 197901010000
# 89:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 11:fcst time 6 hrs:from 197901010000
# 90:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 11:fcst time 6 hrs:from 197901010000
# 91:Temperature:K (instant):regular_gg:hybrid:level 11:fcst time 6 hrs:from 197901010000
# 92:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 11:fcst time 6 hrs:from 197901010000
# 93:Geopotential Height:gpm (instant):regular_gg:hybrid:level 11:fcst time 6 hrs:from 197901010000
# 94:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 11:fcst time 6 hrs:from 197901010000
# 95:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 11:fcst time 6 hrs:from 197901010000
# 96:230:230 (instant):regular_gg:hybrid:level 11:fcst time 6 hrs:from 197901010000
# 97:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 12:fcst time 6 hrs:from 197901010000
# 98:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 12:fcst time 6 hrs:from 197901010000
# 99:Temperature:K (instant):regular_gg:hybrid:level 12:fcst time 6 hrs:from 197901010000
# 100:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 12:fcst time 6 hrs:from 197901010000
# 101:Geopotential Height:gpm (instant):regular_gg:hybrid:level 12:fcst time 6 hrs:from 197901010000
# 102:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 12:fcst time 6 hrs:from 197901010000
# 103:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 12:fcst time 6 hrs:from 197901010000
# 104:230:230 (instant):regular_gg:hybrid:level 12:fcst time 6 hrs:from 197901010000
# 105:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 13:fcst time 6 hrs:from 197901010000
# 106:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 13:fcst time 6 hrs:from 197901010000
# 107:Temperature:K (instant):regular_gg:hybrid:level 13:fcst time 6 hrs:from 197901010000
# 108:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 13:fcst time 6 hrs:from 197901010000
# 109:Geopotential Height:gpm (instant):regular_gg:hybrid:level 13:fcst time 6 hrs:from 197901010000
# 110:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 13:fcst time 6 hrs:from 197901010000
# 111:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 13:fcst time 6 hrs:from 197901010000
# 112:230:230 (instant):regular_gg:hybrid:level 13:fcst time 6 hrs:from 197901010000
# 113:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 14:fcst time 6 hrs:from 197901010000
# 114:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 14:fcst time 6 hrs:from 197901010000
# 115:Temperature:K (instant):regular_gg:hybrid:level 14:fcst time 6 hrs:from 197901010000
# 116:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 14:fcst time 6 hrs:from 197901010000
# 117:Geopotential Height:gpm (instant):regular_gg:hybrid:level 14:fcst time 6 hrs:from 197901010000
# 118:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 14:fcst time 6 hrs:from 197901010000
# 119:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 14:fcst time 6 hrs:from 197901010000
# 120:230:230 (instant):regular_gg:hybrid:level 14:fcst time 6 hrs:from 197901010000
# 121:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 15:fcst time 6 hrs:from 197901010000
# 122:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 15:fcst time 6 hrs:from 197901010000
# 123:Temperature:K (instant):regular_gg:hybrid:level 15:fcst time 6 hrs:from 197901010000
# 124:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 15:fcst time 6 hrs:from 197901010000
# 125:Geopotential Height:gpm (instant):regular_gg:hybrid:level 15:fcst time 6 hrs:from 197901010000
# 126:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 15:fcst time 6 hrs:from 197901010000
# 127:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 15:fcst time 6 hrs:from 197901010000
# 128:230:230 (instant):regular_gg:hybrid:level 15:fcst time 6 hrs:from 197901010000
# 129:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 16:fcst time 6 hrs:from 197901010000
# 130:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 16:fcst time 6 hrs:from 197901010000
# 131:Temperature:K (instant):regular_gg:hybrid:level 16:fcst time 6 hrs:from 197901010000
# 132:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 16:fcst time 6 hrs:from 197901010000
# 133:Geopotential Height:gpm (instant):regular_gg:hybrid:level 16:fcst time 6 hrs:from 197901010000
# 134:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 16:fcst time 6 hrs:from 197901010000
# 135:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 16:fcst time 6 hrs:from 197901010000
# 136:230:230 (instant):regular_gg:hybrid:level 16:fcst time 6 hrs:from 197901010000
# 137:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 17:fcst time 6 hrs:from 197901010000
# 138:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 17:fcst time 6 hrs:from 197901010000
# 139:Temperature:K (instant):regular_gg:hybrid:level 17:fcst time 6 hrs:from 197901010000
# 140:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 17:fcst time 6 hrs:from 197901010000
# 141:Geopotential Height:gpm (instant):regular_gg:hybrid:level 17:fcst time 6 hrs:from 197901010000
# 142:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 17:fcst time 6 hrs:from 197901010000
# 143:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 17:fcst time 6 hrs:from 197901010000
# 144:230:230 (instant):regular_gg:hybrid:level 17:fcst time 6 hrs:from 197901010000
# 145:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 18:fcst time 6 hrs:from 197901010000
# 146:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 18:fcst time 6 hrs:from 197901010000
# 147:Temperature:K (instant):regular_gg:hybrid:level 18:fcst time 6 hrs:from 197901010000
# 148:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 18:fcst time 6 hrs:from 197901010000
# 149:Geopotential Height:gpm (instant):regular_gg:hybrid:level 18:fcst time 6 hrs:from 197901010000
# 150:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 18:fcst time 6 hrs:from 197901010000
# 151:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 18:fcst time 6 hrs:from 197901010000
# 152:230:230 (instant):regular_gg:hybrid:level 18:fcst time 6 hrs:from 197901010000
# 153:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 19:fcst time 6 hrs:from 197901010000
# 154:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 19:fcst time 6 hrs:from 197901010000
# 155:Temperature:K (instant):regular_gg:hybrid:level 19:fcst time 6 hrs:from 197901010000
# 156:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 19:fcst time 6 hrs:from 197901010000
# 157:Geopotential Height:gpm (instant):regular_gg:hybrid:level 19:fcst time 6 hrs:from 197901010000
# 158:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 19:fcst time 6 hrs:from 197901010000
# 159:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 19:fcst time 6 hrs:from 197901010000
# 160:230:230 (instant):regular_gg:hybrid:level 19:fcst time 6 hrs:from 197901010000
# 161:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 20:fcst time 6 hrs:from 197901010000
# 162:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 20:fcst time 6 hrs:from 197901010000
# 163:Temperature:K (instant):regular_gg:hybrid:level 20:fcst time 6 hrs:from 197901010000
# 164:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 20:fcst time 6 hrs:from 197901010000
# 165:Geopotential Height:gpm (instant):regular_gg:hybrid:level 20:fcst time 6 hrs:from 197901010000
# 166:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 20:fcst time 6 hrs:from 197901010000
# 167:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 20:fcst time 6 hrs:from 197901010000
# 168:230:230 (instant):regular_gg:hybrid:level 20:fcst time 6 hrs:from 197901010000
# 169:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 21:fcst time 6 hrs:from 197901010000
# 170:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 21:fcst time 6 hrs:from 197901010000
# 171:Temperature:K (instant):regular_gg:hybrid:level 21:fcst time 6 hrs:from 197901010000
# 172:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 21:fcst time 6 hrs:from 197901010000
# 173:Geopotential Height:gpm (instant):regular_gg:hybrid:level 21:fcst time 6 hrs:from 197901010000
# 174:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 21:fcst time 6 hrs:from 197901010000
# 175:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 21:fcst time 6 hrs:from 197901010000
# 176:230:230 (instant):regular_gg:hybrid:level 21:fcst time 6 hrs:from 197901010000
# 177:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 22:fcst time 6 hrs:from 197901010000
# 178:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 22:fcst time 6 hrs:from 197901010000
# 179:Temperature:K (instant):regular_gg:hybrid:level 22:fcst time 6 hrs:from 197901010000
# 180:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 22:fcst time 6 hrs:from 197901010000
# 181:Geopotential Height:gpm (instant):regular_gg:hybrid:level 22:fcst time 6 hrs:from 197901010000
# 182:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 22:fcst time 6 hrs:from 197901010000
# 183:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 22:fcst time 6 hrs:from 197901010000
# 184:230:230 (instant):regular_gg:hybrid:level 22:fcst time 6 hrs:from 197901010000
# 185:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 23:fcst time 6 hrs:from 197901010000
# 186:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 23:fcst time 6 hrs:from 197901010000
# 187:Temperature:K (instant):regular_gg:hybrid:level 23:fcst time 6 hrs:from 197901010000
# 188:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 23:fcst time 6 hrs:from 197901010000
# 189:Geopotential Height:gpm (instant):regular_gg:hybrid:level 23:fcst time 6 hrs:from 197901010000
# 190:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 23:fcst time 6 hrs:from 197901010000
# 191:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 23:fcst time 6 hrs:from 197901010000
# 192:230:230 (instant):regular_gg:hybrid:level 23:fcst time 6 hrs:from 197901010000
# 193:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 24:fcst time 6 hrs:from 197901010000
# 194:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 24:fcst time 6 hrs:from 197901010000
# 195:Temperature:K (instant):regular_gg:hybrid:level 24:fcst time 6 hrs:from 197901010000
# 196:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 24:fcst time 6 hrs:from 197901010000
# 197:Geopotential Height:gpm (instant):regular_gg:hybrid:level 24:fcst time 6 hrs:from 197901010000
# 198:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 24:fcst time 6 hrs:from 197901010000
# 199:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 24:fcst time 6 hrs:from 197901010000
# 200:230:230 (instant):regular_gg:hybrid:level 24:fcst time 6 hrs:from 197901010000
# 201:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 25:fcst time 6 hrs:from 197901010000
# 202:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 25:fcst time 6 hrs:from 197901010000
# 203:Temperature:K (instant):regular_gg:hybrid:level 25:fcst time 6 hrs:from 197901010000
# 204:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 25:fcst time 6 hrs:from 197901010000
# 205:Geopotential Height:gpm (instant):regular_gg:hybrid:level 25:fcst time 6 hrs:from 197901010000
# 206:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 25:fcst time 6 hrs:from 197901010000
# 207:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 25:fcst time 6 hrs:from 197901010000
# 208:230:230 (instant):regular_gg:hybrid:level 25:fcst time 6 hrs:from 197901010000
# 209:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 26:fcst time 6 hrs:from 197901010000
# 210:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 26:fcst time 6 hrs:from 197901010000
# 211:Temperature:K (instant):regular_gg:hybrid:level 26:fcst time 6 hrs:from 197901010000
# 212:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 26:fcst time 6 hrs:from 197901010000
# 213:Geopotential Height:gpm (instant):regular_gg:hybrid:level 26:fcst time 6 hrs:from 197901010000
# 214:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 26:fcst time 6 hrs:from 197901010000
# 215:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 26:fcst time 6 hrs:from 197901010000
# 216:230:230 (instant):regular_gg:hybrid:level 26:fcst time 6 hrs:from 197901010000
# 217:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 27:fcst time 6 hrs:from 197901010000
# 218:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 27:fcst time 6 hrs:from 197901010000
# 219:Temperature:K (instant):regular_gg:hybrid:level 27:fcst time 6 hrs:from 197901010000
# 220:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 27:fcst time 6 hrs:from 197901010000
# 221:Geopotential Height:gpm (instant):regular_gg:hybrid:level 27:fcst time 6 hrs:from 197901010000
# 222:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 27:fcst time 6 hrs:from 197901010000
# 223:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 27:fcst time 6 hrs:from 197901010000
# 224:230:230 (instant):regular_gg:hybrid:level 27:fcst time 6 hrs:from 197901010000
# 225:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 28:fcst time 6 hrs:from 197901010000
# 226:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 28:fcst time 6 hrs:from 197901010000
# 227:Temperature:K (instant):regular_gg:hybrid:level 28:fcst time 6 hrs:from 197901010000
# 228:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 28:fcst time 6 hrs:from 197901010000
# 229:Geopotential Height:gpm (instant):regular_gg:hybrid:level 28:fcst time 6 hrs:from 197901010000
# 230:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 28:fcst time 6 hrs:from 197901010000
# 231:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 28:fcst time 6 hrs:from 197901010000
# 232:230:230 (instant):regular_gg:hybrid:level 28:fcst time 6 hrs:from 197901010000
# 233:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 29:fcst time 6 hrs:from 197901010000
# 234:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 29:fcst time 6 hrs:from 197901010000
# 235:Temperature:K (instant):regular_gg:hybrid:level 29:fcst time 6 hrs:from 197901010000
# 236:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 29:fcst time 6 hrs:from 197901010000
# 237:Geopotential Height:gpm (instant):regular_gg:hybrid:level 29:fcst time 6 hrs:from 197901010000
# 238:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 29:fcst time 6 hrs:from 197901010000
# 239:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 29:fcst time 6 hrs:from 197901010000
# 240:230:230 (instant):regular_gg:hybrid:level 29:fcst time 6 hrs:from 197901010000
# 241:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 30:fcst time 6 hrs:from 197901010000
# 242:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 30:fcst time 6 hrs:from 197901010000
# 243:Temperature:K (instant):regular_gg:hybrid:level 30:fcst time 6 hrs:from 197901010000
# 244:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 30:fcst time 6 hrs:from 197901010000
# 245:Geopotential Height:gpm (instant):regular_gg:hybrid:level 30:fcst time 6 hrs:from 197901010000
# 246:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 30:fcst time 6 hrs:from 197901010000
# 247:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 30:fcst time 6 hrs:from 197901010000
# 248:230:230 (instant):regular_gg:hybrid:level 30:fcst time 6 hrs:from 197901010000
# 249:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 31:fcst time 6 hrs:from 197901010000
# 250:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 31:fcst time 6 hrs:from 197901010000
# 251:Temperature:K (instant):regular_gg:hybrid:level 31:fcst time 6 hrs:from 197901010000
# 252:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 31:fcst time 6 hrs:from 197901010000
# 253:Geopotential Height:gpm (instant):regular_gg:hybrid:level 31:fcst time 6 hrs:from 197901010000
# 254:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 31:fcst time 6 hrs:from 197901010000
# 255:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 31:fcst time 6 hrs:from 197901010000
# 256:230:230 (instant):regular_gg:hybrid:level 31:fcst time 6 hrs:from 197901010000
# 257:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 32:fcst time 6 hrs:from 197901010000
# 258:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 32:fcst time 6 hrs:from 197901010000
# 259:Temperature:K (instant):regular_gg:hybrid:level 32:fcst time 6 hrs:from 197901010000
# 260:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 32:fcst time 6 hrs:from 197901010000
# 261:Geopotential Height:gpm (instant):regular_gg:hybrid:level 32:fcst time 6 hrs:from 197901010000
# 262:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 32:fcst time 6 hrs:from 197901010000
# 263:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 32:fcst time 6 hrs:from 197901010000
# 264:230:230 (instant):regular_gg:hybrid:level 32:fcst time 6 hrs:from 197901010000
# 265:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 33:fcst time 6 hrs:from 197901010000
# 266:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 33:fcst time 6 hrs:from 197901010000
# 267:Temperature:K (instant):regular_gg:hybrid:level 33:fcst time 6 hrs:from 197901010000
# 268:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 33:fcst time 6 hrs:from 197901010000
# 269:Geopotential Height:gpm (instant):regular_gg:hybrid:level 33:fcst time 6 hrs:from 197901010000
# 270:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 33:fcst time 6 hrs:from 197901010000
# 271:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 33:fcst time 6 hrs:from 197901010000
# 272:230:230 (instant):regular_gg:hybrid:level 33:fcst time 6 hrs:from 197901010000
# 273:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 34:fcst time 6 hrs:from 197901010000
# 274:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 34:fcst time 6 hrs:from 197901010000
# 275:Temperature:K (instant):regular_gg:hybrid:level 34:fcst time 6 hrs:from 197901010000
# 276:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 34:fcst time 6 hrs:from 197901010000
# 277:Geopotential Height:gpm (instant):regular_gg:hybrid:level 34:fcst time 6 hrs:from 197901010000
# 278:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 34:fcst time 6 hrs:from 197901010000
# 279:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 34:fcst time 6 hrs:from 197901010000
# 280:230:230 (instant):regular_gg:hybrid:level 34:fcst time 6 hrs:from 197901010000
# 281:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 35:fcst time 6 hrs:from 197901010000
# 282:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 35:fcst time 6 hrs:from 197901010000
# 283:Temperature:K (instant):regular_gg:hybrid:level 35:fcst time 6 hrs:from 197901010000
# 284:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 35:fcst time 6 hrs:from 197901010000
# 285:Geopotential Height:gpm (instant):regular_gg:hybrid:level 35:fcst time 6 hrs:from 197901010000
# 286:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 35:fcst time 6 hrs:from 197901010000
# 287:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 35:fcst time 6 hrs:from 197901010000
# 288:230:230 (instant):regular_gg:hybrid:level 35:fcst time 6 hrs:from 197901010000
# 289:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 36:fcst time 6 hrs:from 197901010000
# 290:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 36:fcst time 6 hrs:from 197901010000
# 291:Temperature:K (instant):regular_gg:hybrid:level 36:fcst time 6 hrs:from 197901010000
# 292:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 36:fcst time 6 hrs:from 197901010000
# 293:Geopotential Height:gpm (instant):regular_gg:hybrid:level 36:fcst time 6 hrs:from 197901010000
# 294:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 36:fcst time 6 hrs:from 197901010000
# 295:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 36:fcst time 6 hrs:from 197901010000
# 296:230:230 (instant):regular_gg:hybrid:level 36:fcst time 6 hrs:from 197901010000
# 297:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 37:fcst time 6 hrs:from 197901010000
# 298:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 37:fcst time 6 hrs:from 197901010000
# 299:Temperature:K (instant):regular_gg:hybrid:level 37:fcst time 6 hrs:from 197901010000
# 300:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 37:fcst time 6 hrs:from 197901010000
# 301:Geopotential Height:gpm (instant):regular_gg:hybrid:level 37:fcst time 6 hrs:from 197901010000
# 302:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 37:fcst time 6 hrs:from 197901010000
# 303:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 37:fcst time 6 hrs:from 197901010000
# 304:230:230 (instant):regular_gg:hybrid:level 37:fcst time 6 hrs:from 197901010000
# 305:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 38:fcst time 6 hrs:from 197901010000
# 306:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 38:fcst time 6 hrs:from 197901010000
# 307:Temperature:K (instant):regular_gg:hybrid:level 38:fcst time 6 hrs:from 197901010000
# 308:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 38:fcst time 6 hrs:from 197901010000
# 309:Geopotential Height:gpm (instant):regular_gg:hybrid:level 38:fcst time 6 hrs:from 197901010000
# 310:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 38:fcst time 6 hrs:from 197901010000
# 311:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 38:fcst time 6 hrs:from 197901010000
# 312:230:230 (instant):regular_gg:hybrid:level 38:fcst time 6 hrs:from 197901010000
# 313:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 39:fcst time 6 hrs:from 197901010000
# 314:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 39:fcst time 6 hrs:from 197901010000
# 315:Temperature:K (instant):regular_gg:hybrid:level 39:fcst time 6 hrs:from 197901010000
# 316:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 39:fcst time 6 hrs:from 197901010000
# 317:Geopotential Height:gpm (instant):regular_gg:hybrid:level 39:fcst time 6 hrs:from 197901010000
# 318:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 39:fcst time 6 hrs:from 197901010000
# 319:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 39:fcst time 6 hrs:from 197901010000
# 320:230:230 (instant):regular_gg:hybrid:level 39:fcst time 6 hrs:from 197901010000
# 321:U component of wind:m s**-1 (instant):regular_gg:hybrid:level 40:fcst time 6 hrs:from 197901010000
# 322:V component of wind:m s**-1 (instant):regular_gg:hybrid:level 40:fcst time 6 hrs:from 197901010000
# 323:Temperature:K (instant):regular_gg:hybrid:level 40:fcst time 6 hrs:from 197901010000
# 324:Specific humidity:kg kg**-1 (instant):regular_gg:hybrid:level 40:fcst time 6 hrs:from 197901010000
# 325:Geopotential Height:gpm (instant):regular_gg:hybrid:level 40:fcst time 6 hrs:from 197901010000
# 326:Vertical velocity:Pa s**-1 (instant):regular_gg:hybrid:level 40:fcst time 6 hrs:from 197901010000
# 327:Cloud water:kg m**-2 (instant):regular_gg:hybrid:level 40:fcst time 6 hrs:from 197901010000

# %%
uVw = grbs[5]
uVw_values = uVw.values
vVw = grbs[6]
vVw_values = vVw.values

# %%
uVw.values[35][45]
# Out:
# 0.025421142578125

# %%
uVw_values.shape
# Out:
# (160, 320)

# %%
sum = 0
for i in range(0,50):
    sum = sum + uVw_values[1][i] 
avg = sum/50
avg
# Out:
# -10.810203857421875

# %%
lat, lon = uVw.latlons()

# %%
lat[35][45]
# Out:
# 49.906211835711019

# %%
uVw.analDate
# Out:
# datetime.datetime(1979, 1, 1, 0, 0)

# %%
uVw.name
# Out:
# '10 metre U wind component'

# %%
vVw.name
# Out:
# '10 metre V wind component'

# %%
uVw.projparams
# Out:
# {'a': 6367470, 'b': 6367470, 'proj': 'cyl'}

# %%
uVw.projparams == vVw.projparams
# Out:
# True

# %%
uVw.keys()
# Out:
# ['parametersVersion',
#  'UseEcmfConventions',
#  'GRIBEX_boustrophedonic',
#  'hundred',
#  'globalDomain',
#  'GRIBEditionNumber',
#  'eps',
#  'offsetSection0',
#  'section0Length',
#  'totalLength',
#  'editionNumber',
#  'WMO',
#  'productionStatusOfProcessedData',
#  'section1Length',
#  'wrongPadding',
#  'table2Version',
#  'centre',
#  'centreDescription',
#  'generatingProcessIdentifier',
#  'gridDefinition',
#  'indicatorOfParameter',
#  'parameterName',
#  'parameterUnits',
#  'indicatorOfTypeOfLevel',
#  'pressureUnits',
#  'typeOfLevelECMF',
#  'typeOfLevel',
#  'level',
#  'yearOfCentury',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'second',
#  'unitOfTimeRange',
#  'P1',
#  'P2',
#  'timeRangeIndicator',
#  'numberIncludedInAverage',
#  'numberMissingFromAveragesOrAccumulations',
#  'centuryOfReferenceTimeOfData',
#  'subCentre',
#  'paramIdECMF',
#  'paramId',
#  'cfNameECMF',
#  'cfName',
#  'cfVarNameECMF',
#  'cfVarName',
#  'unitsECMF',
#  'units',
#  'nameECMF',
#  'name',
#  'decimalScaleFactor',
#  'setLocalDefinition',
#  'dataDate',
#  'year',
#  'dataTime',
#  'julianDay',
#  'stepUnits',
#  'stepType',
#  'stepRange',
#  'startStep',
#  'endStep',
#  'marsParam',
#  'validityDate',
#  'validityTime',
#  'deleteLocalDefinition',
#  'localUsePresent',
#  'shortNameECMF',
#  'shortName',
#  'ifsParam',
#  'gridDescriptionSectionPresent',
#  'bitmapPresent',
#  'angularPrecision',
#  'section2Length',
#  'radius',
#  'numberOfVerticalCoordinateValues',
#  'neitherPresent',
#  'pvlLocation',
#  'dataRepresentationType',
#  'gridDefinitionDescription',
#  'gridDefinitionTemplateNumber',
#  'Ni',
#  'Nj',
#  'latitudeOfFirstGridPoint',
#  'latitudeOfFirstGridPointInDegrees',
#  'longitudeOfFirstGridPoint',
#  'longitudeOfFirstGridPointInDegrees',
#  'resolutionAndComponentFlags',
#  'ijDirectionIncrementGiven',
#  'earthIsOblate',
#  'resolutionAndComponentFlags3',
#  'resolutionAndComponentFlags4',
#  'uvRelativeToGrid',
#  'resolutionAndComponentFlags6',
#  'resolutionAndComponentFlags7',
#  'resolutionAndComponentFlags8',
#  'latitudeOfLastGridPoint',
#  'latitudeOfLastGridPointInDegrees',
#  'longitudeOfLastGridPoint',
#  'longitudeOfLastGridPointInDegrees',
#  'iDirectionIncrement',
#  'iDirectionIncrementInDegrees',
#  'N',
#  'scanningMode',
#  'iScansNegatively',
#  'jScansPositively',
#  'jPointsAreConsecutive',
#  'alternativeRowScanning',
#  'iScansPositively',
#  'scanningMode4',
#  'scanningMode5',
#  'scanningMode6',
#  'scanningMode7',
#  'scanningMode8',
#  'global',
#  'numberOfDataPoints',
#  'numberOfValues',
#  'latLonValues',
#  'latitudes',
#  'longitudes',
#  'distinctLatitudes',
#  'distinctLongitudes',
#  'isOctahedral',
#  'gaussianGridName',
#  'PVPresent',
#  'PLPresent',
#  'deletePV',
#  'lengthOfHeaders',
#  'missingValue',
#  'tableReference',
#  'section4Length',
#  'halfByte',
#  'dataFlag',
#  'binaryScaleFactor',
#  'referenceValue',
#  'referenceValueError',
#  'sphericalHarmonics',
#  'complexPacking',
#  'integerPointValues',
#  'additionalFlagPresent',
#  'orderOfSPD',
#  'boustrophedonic',
#  'hideThis',
#  'packingType',
#  'bitsPerValue',
#  'constantFieldHalfByte',
#  'bitMapIndicator',
#  'values',
#  'numberOfCodedValues',
#  'packingError',
#  'unpackedError',
#  'maximum',
#  'minimum',
#  'average',
#  'numberOfMissing',
#  'standardDeviation',
#  'skewness',
#  'kurtosis',
#  'isConstant',
#  'dataLength',
#  'changeDecimalPrecision',
#  'decimalPrecision',
#  'bitsPerValueAndRepack',
#  'scaleValuesBy',
#  'offsetValuesBy',
#  'gridType',
#  'getNumberOfValues',
#  'section5Length',
#  'analDate',
#  'validDate']

# %%
uVw['minimum']
# Out:
# -23.365203857421875

# %%
fig = plt.figure(figsize=(8,8))
m = Basemap(projection='lcc',lon_0=-50, lat_0=50, height= 2000e3, width=2000e3,resolution='l')
m.drawcoastlines()
#m.fillcontinents(color='coral', lake_color='aqua')
# draw parallels and meridians
m.drawparallels(np.arange(-80.,81., 10.))
m.drawmeridians(np.arange(-180.,181., 20.))
m.drawmapboundary(fill_color='aqua')

x,y = m(lon,lat)
m.contourf(x,y,uVw_values, np.linspace(-20,20,60),extend='both')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Part 2

# %%
data = pygrib.open("1979010100.grb")

# %%
t_uVw_vVw = np.zeros((36,3))
b = 0
for a in range(0, 36):
    t_uVw_vVw[a,0] = b*6
    b = b + 1

# %%
t_uVw_vVw[2]
# Out:
# array([ 12.,   0.,   0.])

# %%
prefix = "197901"
b = 0

#for i in range(0,1):
for j in range(1,10):
    if j < 10:
        j = "0" + str(j)
    else:
        j = str(j)

    for k in np.arange(0, 19, 6):
        if k < 12:
            k = "0" + str(k)
        else:
            k = str(k)
        filename = prefix + j + k + ".grb"
        data = pygrib.open('/home/evankielley/Downloads/test_gribs/197901/' + filename)
        uVw3545 = data[5].values[35][45]
        vVw3545 = data[6].values[35][45]
        data.close()
        t_uVw_vVw[b,1] = uVw3545
        t_uVw_vVw[b,2] = vVw3545
        b = b + 1

# %%
t_uVw_vVw
# Out:
# array([[  0.00000000e+00,   2.54211426e-02,  -3.94456482e+00],
#        [  6.00000000e+00,  -1.35792542e+00,  -2.06533813e+00],
#        [  1.20000000e+01,  -2.30885315e+00,  -1.11026001e+00],
#        [  1.80000000e+01,  -3.07933044e+00,  -6.24588013e-01],
#        [  2.40000000e+01,  -3.88883972e+00,   3.84735107e-01],
#        [  3.00000000e+01,  -4.83653259e+00,   8.44970703e-01],
#        [  3.60000000e+01,  -4.46185303e+00,   1.65917969e+00],
#        [  4.20000000e+01,  -3.43611145e+00,   2.72669983e+00],
#        [  4.80000000e+01,  -2.19085693e+00,   2.83206177e+00],
#        [  5.40000000e+01,  -1.69250488e-01,   3.06535339e+00],
#        [  6.00000000e+01,   2.78700256e+00,   1.77182007e+00],
#        [  6.60000000e+01,   1.09962463e+00,  -3.90502930e-01],
#        [  7.20000000e+01,  -5.75119019e-01,  -8.98788452e-01],
#        [  7.80000000e+01,  -2.23651123e+00,  -1.08058167e+00],
#        [  8.40000000e+01,  -3.85897827e+00,  -1.19705200e+00],
#        [  9.00000000e+01,  -3.07005310e+00,  -4.05334473e-01],
#        [  9.60000000e+01,   4.97618103e+00,   5.10742188e-01],
#        [  1.02000000e+02,   6.72944641e+00,   3.82781982e-01],
#        [  1.08000000e+02,   4.91007996e+00,   2.99539185e+00],
#        [  1.14000000e+02,   9.62127686e-01,   2.63854980e+00],
#        [  1.20000000e+02,   3.56903076e-02,   3.18821716e+00],
#        [  1.26000000e+02,  -1.82272339e+00,   2.67607117e+00],
#        [  1.32000000e+02,  -1.10102844e+00,   2.85472107e+00],
#        [  1.38000000e+02,   6.21002197e-01,   2.91183472e+00],
#        [  1.44000000e+02,   1.23107910e+00,   1.61723328e+00],
#        [  1.50000000e+02,  -4.54330444e-01,   1.82682800e+00],
#        [  1.56000000e+02,   1.35542297e+00,   1.58348083e+00],
#        [  1.62000000e+02,   1.19519043e+00,   8.24020386e-01],
#        [  1.68000000e+02,   1.45088196e+00,  -5.97122192e-01],
#        [  1.74000000e+02,   4.75906372e-01,  -1.78666687e+00],
#        [  1.80000000e+02,   1.06451416e+00,  -1.90582275e-02],
#        [  1.86000000e+02,   9.04357910e-01,  -2.53906250e-01],
#        [  1.92000000e+02,   1.77450562e+00,   7.67410278e-01],
#        [  1.98000000e+02,   1.04095459e+00,   2.50758362e+00],
#        [  2.04000000e+02,   1.00550842e+00,   3.82087708e+00],
#        [  2.10000000e+02,   5.14556885e-01,   2.88519287e+00]])

# %%
A = t_uVw_vVw
t,U,V = A.T 

fig=plt.figure()
ax = fig.add_subplot(111)
ax.plot(t,U)
ax.plot(t,V)
plt.xticks(np.arange(0, 217, 24))


#plt.plot(t,U) 
#plt.plot(t,V)
#plt.xticks(np.arange(0, 210, 24))
plt.grid(b=True, which='major', color='0.8', linestyle='-')
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>

# %%
filename
# Out:
# '1979010918.grb'

# %%
import random
#random.gauss(0.07619,0.02)
random.gauss(0, 0.02)

# %%
import requests
url = "https://rda.ucar.edu/datasets/ds625.0/index.html#sfol-wl-/data/ds625.0?g=14/197901_0110.fcst_mdl.subc60.tar"
r = requests.get(url, stream=True)

# %%
print(r.headers)

# %%
filename = "my_file.tar"
with open(filename, 'wb') as f:
    f.write(r.content)

# %%
import tarfile    

# Open tarfile
tar = tarfile.open(mode="r:gz", fileobj = f)

# Iterate over every member
for member in tar.getnames():
    # Print contents of every file
    print(tar.extractfile(member).read())

# %%
# fetch.py
from io import StringIO
import gzip
#import requests
# Called a 'tar' file but actually a gzip file. @#$%!!!
#url = "http://example.com/data.tar.gz"
response = requests.get(url)

results = gzip.GzipFile(fileobj=StringIO(response.content))
